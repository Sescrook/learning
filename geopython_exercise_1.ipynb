# %%
ice_cream_rating = 4

# %%
sleeping_rating = 9

# %%
first_name = input()
# Out:
#  Steve

# %%
last_name = input()
# Out:
#  C

# %%
avg_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
happiness_rating = avg_rating

# %%
print (happiness_rating)
# Out:
# 6.5

# %%
type(happiness_rating)
# Out:
# float

# %%
type(first_name)
# Out:
# str

# %%
type(last_name)
# Out:
# str

# %%
type(ice_cream_rating)
# Out:
# int

# %% [markdown]
# I think that these were expected, once dividing two integers, the variable necessarily has to change to float

# %%
print("My name is " + str(first_name) + " and I give eating ice cream a score of " + str(ice_cream_rating) + " out of 10")
# Out:
# My name is Steve and I give eating ice cream a score of 4 out of 10

# %%
print("I am " + str(first_name) + " " + str(last_name) + " and my sleeping enjoyment rating is " + str(sleeping_rating) + " / 10!")
# Out:
# I am Steve C and my sleeping enjoyment rating is 9 / 10!

# %%
print("Based on the factors above, my happiness rating is " + str(avg_rating) + " out of 10!")
# Out:
# Based on the factors above, my happiness rating is 6.5 out of 10!
